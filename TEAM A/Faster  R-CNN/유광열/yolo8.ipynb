# %%
!#pip install ultralytics
#!pip install scikit-learn

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

import pandas as pd
import numpy as np
import cv2
import shutil
import yaml
import warnings
warnings.filterwarnings("ignore")

from ultralytics import YOLO
from glob import glob
from tqdm import tqdm
from IPython.display import clear_output
from sklearn.model_selection import train_test_split

# %%
SEED = 42
BATCH_SIZE = 8
MODEL = "v2"

# %%
if os.path.exists("data/yolo"):
    shutil.rmtree("data/yolo")

if not os.path.exists("data/yolo/train"):
    os.makedirs("data/yolo/train")
    
if not os.path.exists("data/yolo/valid"):
    os.makedirs("data/yolo/valid")
    
if not os.path.exists("data/yolo/test"):
    os.makedirs("data/yolo/test")    
    
if not os.path.exists("results"):
    os.makedirs("results")

# %%
def make_yolo_dataset(image_paths, txt_paths, type="train"):
    for image_path, txt_path in tqdm(zip(image_paths, txt_paths if not type == "test" else image_paths), total=len(image_paths)):
        source_image = cv2.imread(image_path, cv2.IMREAD_COLOR)        
        image_height, image_width, _ = source_image.shape
        
        target_image_path = f"data/yolo/{type}/{os.path.basename(image_path)}"
        cv2.imwrite(target_image_path, source_image)
        
        if type == "test":
            continue
        
        with open(txt_path, "r") as reader:
            yolo_labels = []
            for line in reader.readlines():
                line = list(map(float, line.strip().split(" ")))
                class_name = int(line[0])
                x_min, y_min = float(min(line[5], line[7])), float(min(line[6], line[8]))
                x_max, y_max = float(max(line[1], line[3])), float(max(line[2], line[4]))
                x, y = float(((x_min + x_max) / 2) / image_width), float(((y_min + y_max) / 2) / image_height)
                w, h = abs(x_max - x_min) / image_width, abs(y_max - y_min) / image_height
                yolo_labels.append(f"{class_name} {x} {y} {w} {h}")
            
        target_label_txt = f"data/yolo/{type}/{os.path.basename(txt_path)}"      
        with open(target_label_txt, "w") as writer:
            for yolo_label in yolo_labels:
                writer.write(f"{yolo_label}\n")

# %%
image_paths = sorted(glob("data/train/*.png"))
txt_paths = sorted(glob("data/train/*.txt"))

train_images_paths, valid_images_paths, train_txt_paths, valid_txt_paths = train_test_split(image_paths, txt_paths, test_size=0.1, random_state=SEED)

make_yolo_dataset(train_images_paths, train_txt_paths, "train")
make_yolo_dataset(valid_images_paths, valid_txt_paths, "valid")
make_yolo_dataset(sorted(glob("data/test/*.png")), None, "test")

# %%
with open("data/classes.txt", "r") as reader:
    lines = reader.readlines()
    classes = [line.strip().split(",")[1] for line in lines]

yaml_data = {
              "names": classes,
              "nc": len(classes),
              "path": "data/yolo/",
              "train": "train",
              "val": "valid",
              "test": "test"
            }

with open("data/yolo/custom.yaml", "w") as writer:
    yaml.dump(yaml_data, writer)

# %%
#model = YOLO(f"{MODEL}/train/weights/last.pt")
model = YOLO("yolov8x.pt")
results = model.train(
    data="data\yolo\custom.yaml",
    imgsz=(640, 640),
    epochs=100,
    batch=BATCH_SIZE,
    patience=5,
    workers=16,
    device=0,
    exist_ok=True,    
    project=f"{MODEL}",
    name="train",
    seed=SEED,
    #pretrained=False,
    #resume=False,
    optimizer="AdamW",
    lr0=1e-3,
    augment=True,
    val=True,
    cache=True
    )
# Out:
# New https://pypi.org/project/ultralytics/8.0.112 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.109  Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# yolo\engine\trainer: task=detect, mode=train, model=yolov8x.pt, data=data\yolo\custom.yaml, epochs=100, patience=5, batch=8, imgsz=(640, 640), save=True, save_period=-1, cache=True, device=0, workers=16, project=v2, name=train, exist_ok=True, pretrained=False, optimizer=AdamW, verbose=True, seed=42, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=True, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=v2\train
# Overriding model.yaml nc=80 with nc=34
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8750710  ultralytics.nn.modules.head.Detect           [34, [320, 640, 640]]
# Model summary: 365 layers, 68185350 parameters, 68185334 gradients
#
# Transferred 589/595 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed
# WARNING  updating to 'imgsz=640'. 'train' and 'val' imgsz must be an integer, while 'predict' and 'export' imgsz may be a [h, w] list or an integer, i.e. 'yolo export imgsz=640,480' or 'yolo export imgsz=640'
# optimizer: AdamW(lr=0.001) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias
# train: Scanning C:\Users\pc\Desktop\KMU\Project\Dacon Detection\data\yolo\train.cache... 5832 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5832/5832 [00:00<?, ?it/s]
# train: Caching images (3.6GB True): 100%|██████████| 5832/5832 [00:26<00:00, 219.36it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning C:\Users\pc\Desktop\KMU\Project\Dacon Detection\data\yolo\valid.cache... 649 images, 0 backgrounds, 0 corrupt: 100%|██████████| 649/649 [00:00<?, ?it/s]
# val: Caching images (0.4GB True): 100%|██████████| 649/649 [00:03<00:00, 167.51it/s]
# Plotting labels to v2\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to v2\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       7.5G     0.2902     0.9317     0.8405         37        640: 100%|██████████| 729/729 [06:31<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.23it/s]
#                    all        649       1709      0.967      0.941      0.994      0.984
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.46G     0.2629     0.4697      0.827         50        640: 100%|██████████| 729/729 [06:16<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.23it/s]
#                    all        649       1709       0.99       0.99      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.47G     0.2465     0.4035     0.8208         49        640: 100%|██████████| 729/729 [06:18<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.21it/s]
#                    all        649       1709      0.996          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.46G     0.2221     0.3524      0.814         48        640: 100%|██████████| 729/729 [06:09<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.10it/s]
#                    all        649       1709      0.995      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      7.48G       0.21     0.3258     0.8114         32        640: 100%|██████████| 729/729 [05:49<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.17it/s]
#                    all        649       1709      0.997      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.47G     0.1964      0.298     0.8069         26        640: 100%|██████████| 729/729 [06:10<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.08it/s]
#                    all        649       1709      0.997          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.39G     0.1825     0.2624     0.8014         49        640: 100%|██████████| 729/729 [06:28<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.24it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.39G     0.1791     0.2629     0.8009         39        640: 100%|██████████| 729/729 [06:21<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.07it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.41G     0.1766     0.2551     0.8014         36        640: 100%|██████████| 729/729 [06:04<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.38it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.45G     0.1697     0.2438     0.8004         44        640: 100%|██████████| 729/729 [05:56<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.15it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.45G     0.1644     0.2375     0.7969         53        640: 100%|██████████| 729/729 [05:48<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.19it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      7.47G     0.1635      0.229     0.7974         39        640: 100%|██████████| 729/729 [06:15<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  2.97it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.47G     0.1607     0.2224     0.7973         40        640: 100%|██████████| 729/729 [06:32<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.14it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      7.49G     0.1577     0.2199     0.7976         26        640: 100%|██████████| 729/729 [06:28<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.14it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100       7.4G     0.1566     0.2188     0.7969         42        640: 100%|██████████| 729/729 [06:13<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.17it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      7.38G     0.1511     0.2072     0.7962         42        640: 100%|██████████| 729/729 [06:28<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.04it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100       7.4G      0.149     0.2027     0.7941         42        640: 100%|██████████| 729/729 [06:24<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.03it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      7.44G     0.1489     0.2008     0.7936         34        640: 100%|██████████| 729/729 [06:29<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.15it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      7.45G     0.1454     0.1965     0.7948         50        640: 100%|██████████| 729/729 [06:19<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.14it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      7.45G      0.143     0.1887     0.7934         51        640: 100%|██████████| 729/729 [06:27<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:14<00:00,  2.89it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      7.44G     0.1456     0.1938     0.7937         48        640: 100%|██████████| 729/729 [06:26<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.06it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      7.45G      0.142     0.1846     0.7923         39        640: 100%|██████████| 729/729 [06:24<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.08it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100       7.4G     0.1384     0.1832     0.7921         35        640: 100%|██████████| 729/729 [06:36<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  2.94it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      7.39G     0.1376     0.1805     0.7922         58        640: 100%|██████████| 729/729 [06:28<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.10it/s]
#                    all        649       1709      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      7.38G     0.1382     0.1772     0.7931         43        640: 100%|██████████| 729/729 [06:28<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  2.97it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      7.43G     0.1347     0.1682      0.791         34        640: 100%|██████████| 729/729 [06:33<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.00it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      7.41G     0.1338     0.1699      0.791         38        640: 100%|██████████| 729/729 [06:02<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.29it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      7.44G     0.1365     0.1703      0.791         43        640: 100%|██████████| 729/729 [06:00<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.32it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      7.44G     0.1318     0.1659     0.7912         34        640: 100%|██████████| 729/729 [05:50<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.31it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      7.46G      0.132     0.1659     0.7891         43        640: 100%|██████████| 729/729 [05:59<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.33it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      7.39G     0.1314     0.1624     0.7904         34        640: 100%|██████████| 729/729 [06:01<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.23it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      7.39G     0.1315     0.1659     0.7909         33        640: 100%|██████████| 729/729 [06:00<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.40it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      7.39G     0.1319     0.1632     0.7896         35        640: 100%|██████████| 729/729 [05:36<00:00,  2.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.30it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      7.45G     0.1265     0.1508     0.7877         38        640: 100%|██████████| 729/729 [06:00<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.34it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      7.48G     0.1257     0.1516     0.7891         30        640: 100%|██████████| 729/729 [06:00<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.31it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      7.46G     0.1247     0.1508     0.7899         49        640: 100%|██████████| 729/729 [06:03<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.11it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      7.45G     0.1247     0.1479      0.788         73        640: 100%|██████████| 729/729 [06:23<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.07it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      7.47G     0.1245     0.1475     0.7896         37        640: 100%|██████████| 729/729 [06:12<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.20it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      7.38G     0.1253     0.1488     0.7904         42        640: 100%|██████████| 729/729 [06:15<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.20it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      7.38G     0.1211     0.1406     0.7882         43        640: 100%|██████████| 729/729 [05:49<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.19it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      7.42G     0.1197     0.1443      0.787         50        640: 100%|██████████| 729/729 [06:14<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.12it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      7.45G     0.1199     0.1406     0.7875         34        640: 100%|██████████| 729/729 [06:09<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.03it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      7.46G     0.1187     0.1368     0.7878         44        640: 100%|██████████| 729/729 [06:31<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.09it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      7.45G     0.1175     0.1345     0.7875         36        640: 100%|██████████| 729/729 [06:46<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:14<00:00,  2.79it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      7.47G     0.1163     0.1312      0.787         39        640: 100%|██████████| 729/729 [06:36<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.09it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      7.44G     0.1167      0.135     0.7859         51        640: 100%|██████████| 729/729 [06:41<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.05it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      7.39G     0.1148     0.1288     0.7861         38        640: 100%|██████████| 729/729 [06:32<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.02it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      7.39G      0.116     0.1311     0.7861         53        640: 100%|██████████| 729/729 [06:58<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.09it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100       7.4G     0.1145     0.1302     0.7865         38        640: 100%|██████████| 729/729 [06:32<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  2.97it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      7.47G     0.1129     0.1256      0.786         52        640: 100%|██████████| 729/729 [06:33<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.05it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      7.44G     0.1137     0.1245     0.7852         55        640: 100%|██████████| 729/729 [06:31<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.02it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      7.44G     0.1129     0.1265     0.7873         35        640: 100%|██████████| 729/729 [06:46<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.16it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      7.47G     0.1123     0.1237     0.7865         51        640: 100%|██████████| 729/729 [06:42<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.13it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.48G     0.1101     0.1226     0.7868         43        640: 100%|██████████| 729/729 [06:32<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.12it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      7.37G     0.1097     0.1204     0.7855         38        640: 100%|██████████| 729/729 [06:22<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.42it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      7.39G     0.1085     0.1161     0.7854         41        640: 100%|██████████| 729/729 [05:53<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.41it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      7.43G     0.1094     0.1173     0.7852         42        640: 100%|██████████| 729/729 [05:34<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.38it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      7.42G     0.1078     0.1171      0.786         38        640: 100%|██████████| 729/729 [05:54<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.32it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      7.41G     0.1084     0.1174      0.784         41        640: 100%|██████████| 729/729 [05:51<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:11<00:00,  3.46it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      7.44G     0.1066     0.1123     0.7855         31        640: 100%|██████████| 729/729 [05:50<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.37it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      7.46G     0.1055     0.1091     0.7843         29        640: 100%|██████████| 729/729 [05:53<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.31it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      7.44G     0.1058     0.1106     0.7853         45        640: 100%|██████████| 729/729 [05:55<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.39it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      7.41G     0.1028     0.1075     0.7847         43        640: 100%|██████████| 729/729 [05:51<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.41it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      7.37G     0.1037     0.1074     0.7841         36        640: 100%|██████████| 729/729 [05:57<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.29it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100       7.4G      0.103     0.1074     0.7855         56        640: 100%|██████████| 729/729 [06:11<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.05it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      7.47G     0.1047      0.107     0.7843         63        640: 100%|██████████| 729/729 [06:18<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.12it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      7.46G     0.1026     0.1028     0.7834         32        640: 100%|██████████| 729/729 [05:58<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.16it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      7.47G     0.1025     0.1036     0.7831         30        640: 100%|██████████| 729/729 [06:19<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.15it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      7.48G     0.1017     0.1027      0.784         37        640: 100%|██████████| 729/729 [06:10<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.26it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      7.48G     0.1015     0.1026     0.7846         51        640: 100%|██████████| 729/729 [05:52<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.38it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      7.39G    0.09986     0.1007     0.7837         44        640: 100%|██████████| 729/729 [05:40<00:00,  2.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.23it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      7.39G     0.1008    0.09872     0.7832         33        640: 100%|██████████| 729/729 [06:28<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  2.98it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.39G    0.09985     0.1002     0.7845         51        640: 100%|██████████| 729/729 [06:56<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.08it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.44G    0.09792    0.09814     0.7835         46        640: 100%|██████████| 729/729 [06:34<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.02it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      7.46G    0.09744    0.09646     0.7827         37        640: 100%|██████████| 729/729 [06:57<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.06it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      7.49G    0.09723    0.09558     0.7827         45        640: 100%|██████████| 729/729 [06:34<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:14<00:00,  2.88it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      7.46G    0.09747    0.09901     0.7828         27        640: 100%|██████████| 729/729 [06:41<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.06it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      7.49G    0.09612     0.0934     0.7824         39        640: 100%|██████████| 729/729 [06:42<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:14<00:00,  2.80it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100       7.4G    0.09462    0.09286     0.7835         36        640: 100%|██████████| 729/729 [06:51<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.08it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.38G    0.09327    0.08938     0.7841         52        640: 100%|██████████| 729/729 [06:59<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.05it/s]
#                    all        649       1709      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100       7.4G    0.09342    0.09046     0.7825         36        640: 100%|██████████| 729/729 [06:33<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.00it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.44G    0.09344    0.09092     0.7824         36        640: 100%|██████████| 729/729 [06:55<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.05it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.43G    0.09283    0.08911     0.7832         40        640: 100%|██████████| 729/729 [06:40<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:14<00:00,  2.87it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.46G    0.09205    0.08728     0.7837         40        640: 100%|██████████| 729/729 [06:02<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.05it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.48G    0.09185      0.087     0.7812         41        640: 100%|██████████| 729/729 [06:34<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.04it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100       7.5G     0.0906     0.0851      0.782         39        640: 100%|██████████| 729/729 [06:39<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:14<00:00,  2.90it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.39G    0.09024    0.08307     0.7812         41        640: 100%|██████████| 729/729 [06:14<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:11<00:00,  3.46it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.41G    0.08944    0.08284     0.7814         41        640: 100%|██████████| 729/729 [05:45<00:00,  2.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.36it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.43G    0.08988    0.08203     0.7815         54        640: 100%|██████████| 729/729 [05:49<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.41it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.45G    0.08842    0.07944     0.7811         43        640: 100%|██████████| 729/729 [05:42<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.39it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.44G    0.08732    0.07917     0.7826         46        640: 100%|██████████| 729/729 [05:51<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:11<00:00,  3.44it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.46G    0.08731    0.07916     0.7811         45        640: 100%|██████████| 729/729 [05:40<00:00,  2.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.38it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.48G    0.08619    0.07637     0.7817         39        640: 100%|██████████| 729/729 [05:57<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:11<00:00,  3.43it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.48G    0.08589    0.07705     0.7803         47        640: 100%|██████████| 729/729 [05:34<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.41it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.41G    0.08572    0.07664     0.7815         44        640: 100%|██████████| 729/729 [05:52<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.38it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.41G    0.08497    0.07433     0.7807         49        640: 100%|██████████| 729/729 [05:47<00:00,  2.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.39it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.39G    0.08423    0.07356     0.7807         51        640: 100%|██████████| 729/729 [06:06<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.15it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100       7.4G    0.08421    0.07281     0.7811         42        640: 100%|██████████| 729/729 [06:20<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.09it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       7.4G    0.08387    0.07119     0.7805         51        640: 100%|██████████| 729/729 [06:20<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.19it/s]
#                    all        649       1709          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.41G    0.08313    0.07076     0.7799         34        640: 100%|██████████| 729/729 [06:05<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.10it/s]
#                    all        649       1709          1          1      0.995      0.995
#
# 100 epochs completed in 10.863 hours.
# Optimizer stripped from v2\train\weights\last.pt, 136.7MB
# Optimizer stripped from v2\train\weights\best.pt, 136.7MB
#
# Validating v2\train\weights\best.pt...
# Ultralytics YOLOv8.0.109  Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Model summary (fused): 268 layers, 68156310 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:12<00:00,  3.33it/s]
#                    all        649       1709          1          1      0.995      0.995
# chevrolet_malibu_sedan_2012_2016        649         46          1          1      0.995      0.995
# chevrolet_malibu_sedan_2017_2019        649         51          1          1      0.995      0.995
# chevrolet_spark_hatchback_2016_2021        649         44      0.999          1      0.995      0.995
# chevrolet_trailblazer_suv_2021_        649         45          1          1      0.995      0.995
# chevrolet_trax_suv_2017_2019        649         47      0.999          1      0.995      0.995
# genesis_g80_sedan_2016_2020        649         63          1          1      0.995      0.995
# genesis_g80_sedan_2021_        649         41          1          1      0.995      0.995
# genesis_gv80_suv_2020_        649         50          1          1      0.995      0.995
# hyundai_avante_sedan_2011_2015        649         54          1          1      0.995      0.995
# hyundai_avante_sedan_2020_        649         43      0.999          1      0.995      0.995
# hyundai_grandeur_sedan_2011_2016        649         45          1          1      0.995      0.995
# hyundai_grandstarex_van_2018_2020        649         56      0.999          1      0.995      0.995
# hyundai_ioniq_hatchback_2016_2019        649         47          1          1      0.995      0.995
# hyundai_sonata_sedan_2004_2009        649         46          1          1      0.995      0.995
# hyundai_sonata_sedan_2010_2014        649         54          1          1      0.995      0.995
# hyundai_sonata_sedan_2019_2020        649         52          1          1      0.995      0.995
# kia_carnival_van_2015_2020        649         50          1          1      0.995      0.995
# kia_carnival_van_2021_        649         50          1          1      0.995      0.995
# kia_k5_sedan_2010_2015        649         51          1          1      0.995      0.995
#     kia_k5_sedan_2020_        649         54          1          1      0.995      0.995
# kia_k7_sedan_2016_2020        649         58          1          1      0.995      0.995
#   kia_mohave_suv_2020_        649         44          1          1      0.995      0.995
# kia_morning_hatchback_2004_2010        649         54          1          1      0.995      0.995
# kia_morning_hatchback_2011_2016        649         51          1          1      0.995      0.995
# kia_ray_hatchback_2012_2017        649         52          1          1      0.995      0.995
# kia_sorrento_suv_2015_2019        649         43          1          1      0.995      0.995
# kia_sorrento_suv_2020_        649         55          1          1      0.995      0.995
# kia_soul_suv_2014_2018        649         59          1          1      0.995      0.995
# kia_sportage_suv_2016_2020        649         43          1          1      0.995      0.995
# kia_stonic_suv_2017_2019        649         51          1          1      0.995      0.995
# renault_sm3_sedan_2015_2018        649         44          1          1      0.995      0.995
#  renault_xm3_suv_2020_        649         54          1          1      0.995      0.995
# ssangyong_korando_suv_2019_2020        649         66      0.999          1      0.995      0.995
# ssangyong_tivoli_suv_2016_2020        649         46          1          1      0.995      0.995
# Speed: 0.1ms preprocess, 9.0ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to v2\train

# %%
def get_test_image_paths(test_image_paths):    
    for i in range(0, len(test_image_paths), BATCH_SIZE):
        yield test_image_paths[i:i+BATCH_SIZE]

# %%
model = YOLO("v2/train/weights/best.pt")
test_image_paths = glob("data/yolo/test/*.png")
for i, image in tqdm(enumerate(get_test_image_paths(test_image_paths)), total=int(len(test_image_paths)/BATCH_SIZE)):
    model.predict(image, imgsz=(512, 512), iou=0.2, conf=0.5, save_conf=True, save=False, save_txt=True, project=f"{MODEL}", name="predict",
                  exist_ok=True, device=0, augment=True, verbose=False)
    if i % 5 == 0:
        clear_output(wait=True)
# Out:
#  99%|█████████▉| 421/425 [06:16<00:02,  1.67it/s]Results saved to v2\predict
# 3400 labels saved to v2\predict\labels
#  99%|█████████▉| 422/425 [06:17<00:01,  1.67it/s]Results saved to v2\predict
# 3400 labels saved to v2\predict\labels
# 100%|█████████▉| 423/425 [06:18<00:01,  1.68it/s]Results saved to v2\predict
# 3400 labels saved to v2\predict\labels
# 100%|█████████▉| 424/425 [06:18<00:00,  1.69it/s]Results saved to v2\predict
# 3400 labels saved to v2\predict\labels
# 100%|██████████| 425/425 [06:19<00:00,  1.12it/s]

# %%
def yolo_to_labelme(line, image_width, image_height, txt_file_name):    
    file_name = txt_file_name.split("/")[-1].replace(".txt", ".png")
    class_id, x, y, width, height, confidence = [float(temp) for temp in line.split()]
    
    x_min = int((x - width / 2) * image_width)
    x_max = int((x + width / 2) * image_width)
    y_min = int((y - height / 2) * image_height)
    y_max = int((y + height / 2) * image_height)
    
    return file_name, int(class_id), confidence, x_min, y_min, x_max, y_min, x_max, y_max, x_min, y_max

# %%
infer_txts = glob(f"{MODEL}/predict/labels/*.txt")

results = []
for infer_txt in tqdm(infer_txts):
    base_file_name = infer_txt.split("/")[-1].split(".")[0].split("\\")[1]
    imgage_height, imgage_width = cv2.imread(f"data/test/{base_file_name}.png").shape[:2]        
    with open(infer_txt, "r") as reader:        
        lines = reader.readlines()        
        for line in lines:
            results.append(yolo_to_labelme(line, imgage_width, imgage_height, infer_txt))

df_submission = pd.DataFrame(data=results, columns=["file_name", "class_id", "confidence", "point1_x", "point1_y", "point2_x", "point2_y", "point3_x", "point3_y", "point4_x", "point4_y"])
df_submission['file_name'] = df_submission.file_name.apply(lambda x : x.split("\\")[1])
df_submission.to_csv(f"Submission/YOLO8x_V2_epoch200_Adamw_640_2.csv", index=False)
# Out:
# 100%|██████████| 3400/3400 [02:03<00:00, 27.49it/s]

# %%
df_submission
# Out:
#            file_name  class_id  confidence  point1_x  point1_y  point2_x
# 0      064442001.png        14    0.815659      1137       180      1427  \
# 1      064442001.png         7    0.558712      1137       181      1428
# 2      064442001.png         7    0.974962      1139       182      1430
# 3      064442001.png        16    0.900185      1140       182      1432
# 4      064442001.png        16    0.929843      1138       182      1430
# ...              ...       ...         ...       ...       ...       ...
# 28747  184121675.png        27    0.956841       876       551      1151
# 28748  184121675.png        27    0.973454       877       554      1150
# 28749  184121675.png        27    0.976038       876       552      1151
# 28750  184121675.png        22    0.839533       875       547      1152
# 28751  184121675.png        27    0.975786       878       554      1149
#
#        point2_y  point3_x  point3_y  point4_x  point4_y
# 0           180      1427       492      1137       492
# 1           181      1428       498      1137       498
# 2           182      1430       494      1139       494
# 3           182      1432       493      1140       493
# 4           182      1430       495      1138       495
# ...         ...       ...       ...       ...       ...
# 28747       551      1151       860       876       860
# 28748       554      1150       862       877       862
# 28749       552      1151       861       876       861
# 28750       547      1152       864       875       864
# 28751       554      1149       863       878       863
#
# [28752 rows x 11 columns]

# %%
df_submission.to_csv(f"Submission/YOLO8_V2_epoch100.csv", index=False)
